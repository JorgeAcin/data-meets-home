# %%
import pandas as pd

# Cargar el archivo Excel
estaciones_metro = 'C:/Users/rtorr/OneDrive/Documentos/uni/4º/Proyecto II/estaciones_metro_valencia.xlsx'
df = pd.read_excel(estaciones_metro, engine='openpyxl')

# Mostrar las primeras filas del archivo
print(df.head())
lista_tuplas = list(df[['Latitud', 'Longitud']].itertuples(index=False, name=None))
print(lista_tuplas[:5])  # Mostrar las primeras 5 tuplas
# Out:
#                     Nombre    Latitud  Longitud
# 0              Sant Isidre  39.451070 -0.402617
# 1          Vicent Zaragozà  39.483305 -0.357290
# 2  Universitat Politècnica  39.481184 -0.350014
# 3              la Carrasca  39.479595 -0.344500
# 4   Tarongers Ernest Lluch  39.478163 -0.339534
# [(39.4510701, -0.4026173), (39.4833051, -0.3572899), (39.4811835, -0.3500137), (39.479595, -0.3444999), (39.4781633, -0.3395337)]
